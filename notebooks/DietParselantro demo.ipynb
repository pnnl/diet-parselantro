# %%
import os, json, imp
import numpy as np
import pandas as pd
import tqdm

# %%
import torch
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM

from sentence_transformers import SentenceTransformer

import umap

def get_embedding(text, n_components=None):
    model = SentenceTransformer('bert-base-nli-mean-tokens')
    embeddings = np.vstack(model.encode(text))

    if n_components:
        return umap.UMAP(n_components=n_components).fit_transform(embeddings)
    return embeddings

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
from react_jupyter_widget_example import DietParselantro

# %%
url = 'http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Musical_Instruments_5.json.gz'
df = pd.read_json(url, compression='gzip', lines=True)

# %%
df['clean_text'] = df['reviewText'].str.lower()
df = df.iloc[0:250]
df
# Out:
#          reviewerID        asin  \
# 0    A2IBPI20UZIR0U  1384719342
# 1    A14VAT5EAX3D9S  1384719342
# 2    A195EZSQDW3E21  1384719342
# 3    A2C00NNG1ZQQG2  1384719342
# 4     A94QU4C90B1AX  1384719342
# ..              ...         ...
# 245  A37AQI4AU3JWSR  B0001FTVD6
# 246   AUK79PXTAOJP9  B0001FTVD6
# 247  A2PN3GY7I3EKC1  B0001FTVD6
# 248  A3CSSZ6U5J4YS5  B0001FTVD6
# 249  A1S0HTDO0P4N5V  B0001FTVD6
#
#                                          reviewerName   helpful  \
# 0    cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                                Jake  [13, 14]
# 2                       Rick Bennette "Rick Bennette"    [1, 1]
# 3                           RustyBill "Sunday Rocker"    [0, 0]
# 4                                       SEAN MASLANKA    [0, 0]
# ..                                                ...       ...
# 245                                            Joshua    [0, 0]
# 246                                            ~ Kyle    [0, 0]
# 247                              N. McArthur "MyTech"    [0, 0]
# 248                                          overbybr    [0, 0]
# 249         R. Wristen "The Party Doc VJ and Karaoke"    [0, 0]
#
#                                             reviewText  overall  \
# 0    Not much to write about here, but it does exac...        5
# 1    The product does exactly as it should and is q...        5
# 2    The primary job of this device is to block the...        5
# 3    Nice windscreen protects my MXL mic and preven...        5
# 4    This pop filter is great. It looks and perform...        5
# ..                                                 ...      ...
# 245  Donr be fooled by the imitations... should be ...        5
# 246  Great rack mount screws. Rubber washers are pe...        5
# 247  Other than that, when you need 10-32 rack scre...        5
# 248  There are other rack screws out there, but Rax...        5
# 249  Well if this review survives the censors just ...        5
#
#                                                summary  unixReviewTime  \
# 0                                                 good      1393545600
# 1                                                 Jake      1363392000
# 2                                 It Does The Job Well      1377648000
# 3                        GOOD WINDSCREEN FOR THE MONEY      1392336000
# 4                No more pops when I record my vocals.      1392940800
# ..                                                 ...             ...
# 245                   Best rack screws for your money.      1355788800
# 246                                              Great      1373241600
# 247  25 Screws.... why not 24?  Even numbers would ...      1402963200
# 248                                 As good as it gets      1403827200
# 249           Get Screwed!  That's what they are for!!      1364860800
#
#       reviewTime                                         clean_text
# 0    02 28, 2014  not much to write about here, but it does exac...
# 1    03 16, 2013  the product does exactly as it should and is q...
# 2    08 28, 2013  the primary job of this device is to block the...
# 3    02 14, 2014  nice windscreen protects my mxl mic and preven...
# 4    02 21, 2014  this pop filter is great. it looks and perform...
# ..           ...                                                ...
# 245  12 18, 2012  donr be fooled by the imitations... should be ...
# 246   07 8, 2013  great rack mount screws. rubber washers are pe...
# 247  06 17, 2014  other than that, when you need 10-32 rack scre...
# 248  06 27, 2014  there are other rack screws out there, but rax...
# 249   04 2, 2013  well if this review survives the censors just ...
#
# [250 rows x 10 columns]

# %%
n_components = 16
embedding_path = f'embeddings/parsed_page_content_{n_components}d_embedding.csv'

text = df.clean_text

if not os.path.exists(embedding_path):
    emb = pd.DataFrame(get_embedding(text), index=text.index)
    emb.to_csv(embedding_path)
else:
    emb = pd.read_csv(embedding_path).loc[text.index]
    emb = emb.drop(columns=['Unnamed: 0'])

# %%
# Hierarchical categories can be defined with a . separator
regex = {"filter": "filter",
         "cable": "cable(s?)",
         "cable.piano accessories": "piano|keyboard|pedal"}

# %%
# Instantiate DietParselantro with some regex categories defined
DietParselantro(data=df, regex=pd.Series(regex), embedding=emb)
# Out:
# DietParselantro(component='DietParselantro', props={'data': [{'reviewerID': 'A2IBPI20UZIR0U', 'asin': '1384719…

# %%
# Instantiate DietParselantro without regex categories defined
DietParselantro(data=df, regex=pd.Series({}), embedding=emb)
# Out:
# /opt/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
# DietParselantro(component='DietParselantro', props={'data': [{'reviewerID': 'A2IBPI20UZIR0U', 'asin': '1384719…
